# %% [markdown]
# # Set 03
# * For all the questions you can self-check whether your solution creates the right output (or not)
# * Your code solution should generate an output similar to the 'Expected output' shown against every question. __Avoid running this cell as it will overwrite the displayed output__

# %% [markdown]
# # Q1
# ### Four lists are used to store the information of 5 movies:
# * __m_name = ['Prometheus','Split','Sing','Suicide Squad','The Great Wall']__
# * __yr_of_release = [2012,2016,2015,2014,2017]__
# * __rating = [8.1,7.5,6.7,5.3,7.1,7.9]__
# * __num_reviews = [485820,157606,60545,393727,56036]__
#
# ### Pass a movie name against a variable 'movie_name' and display all its information as shown in 'expected output' cell below:

# %%
m_name = ['Prometheus','Split','Sing','Suicide Squad','The Great Wall']
yr_of_release = [2012,2016,2015,2014,2017]
rating = [8.1,7.5,6.7,5.3,7.1,7.9]
num_reviews = [485820,157606,60545,393727,56036]

#------------Code line where the movie name is passed------
movie_name = 'Sing'

#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#--------Expected Output-----------
# Out:
# Sing 2015 6.7 60545

# %% [markdown]
# # Q2
#
# ### The nested list 'movies_info' stores information of multiple movies. For the First and Last movies display the Director Names

# %%
movies_info = [['The Dark Knight', 2008, 9, 1791916, 'Christopher Nolan'],
 ['Inception', 2010, 8.8, 1583625, 'Christopher Nolan'],
 ['Dangal', 2016, 8.8, 48969, 'Nitesh Tiwari'],
 ['Interstellar', 2014, 8.6, 1047747, 'Christopher Nolan'],
 ['Kimi no na wa', 2016, 8.6, 34110, 'Makoto Shinkai'],
 ['The Intouchables', 2011, 8.6, 557965, 'Olivier Nakache'],
 ['The Prestige', 2006, 8.5, 913152, 'Christopher Nolan'],
 ['The Departed', 2006, 8.5, 937414, 'Martin Scorsese'],
 ['The Dark Knight Rises', 2012, 8.5, 1222645, 'Christopher Nolan'],
 ['Whiplash', 2014, 8.5, 477276, 'Damien Chazelle']]

#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#--------Expected Output-----------
# Out:
# Director of the movie The Dark Knight is Christopher Nolan
# Director of the movie Whiplash is Damien Chazelle

# %% [markdown]
# # Q3
# You are given a List 'movies' with information of multiple movies. Using just slicing, extract all the below attributes in separate lists *(assume all of the below five attributes are provided for each movie and their order is consistent throughout the list 'movies')*
# 1. Movie Name
# 2. Year of Release
# 3. Rating
# 4. Number of Reviews
# 5. Director Name

# %%
movies = ['The Dark Knight', 2008, 9, 1791916, 'Christopher Nolan',
          'Inception', 2010, 8.8, 1583625, 'Christopher Nolan',
          'Dangal', 2016, 8.8, 48969, 'Nitesh Tiwari',
          'Interstellar', 2014, 8.6, 1047747, 'Christopher Nolan',
          'Kimi no na wa', 2016, 8.6, 34110, 'Makoto Shinkai',
          'The Intouchables', 2011, 8.6, 557965, 'Olivier Nakache',
          'The Prestige', 2006, 8.5, 913152, 'Christopher Nolan',
          'The Departed', 2006, 8.5, 937414, 'Martin Scorsese',
          'The Dark Knight Rises', 2012, 8.5, 1222645, 'Christopher Nolan',
          'Whiplash', 2014, 8.5, 477276, 'Damien Chazelle']

# %%
#---------Write your code here--------
#---------Write your code here--------
#---------Write your code here--------

# %%
#--------Expected Output-----------
# Out:
# ['The Dark Knight', 'Inception', 'Dangal', 'Interstellar', 'Kimi no na wa', 'The Intouchables', 'The Prestige', 'The Departed', 'The Dark Knight Rises', 'Whiplash']
# [2008, 2010, 2016, 2014, 2016, 2011, 2006, 2006, 2012, 2014]
# [9, 8.8, 8.8, 8.6, 8.6, 8.6, 8.5, 8.5, 8.5, 8.5]
# [1791916, 1583625, 48969, 1047747, 34110, 557965, 913152, 937414, 1222645, 477276]
# ['Christopher Nolan', 'Christopher Nolan', 'Nitesh Tiwari', 'Christopher Nolan', 'Makoto Shinkai', 'Olivier Nakache', 'Christopher Nolan', 'Martin Scorsese', 'Christopher Nolan', 'Damien Chazelle']

# %% [markdown]
# # Q4
# Using the above provided List 'movies', create a Nested List (. i.e., lists within a List), where all the attributes pertaining to a single movie are stored in a sub-list *(assume all five attributes are provided for each movie and their order is consistent throughout the list 'movies')*

# %%
#---------Write your code here--------
#---------Write your code here--------
#---------Write your code here--------

# %%
#--------Expected Output-----------
# Out:
# [['The Dark Knight', 2008, 9, 1791916, 'Christopher Nolan'],
#  ['Inception', 2010, 8.8, 1583625, 'Christopher Nolan'],
#  ['Dangal', 2016, 8.8, 48969, 'Nitesh Tiwari'],
#  ['Interstellar', 2014, 8.6, 1047747, 'Christopher Nolan'],
#  ['Kimi no na wa', 2016, 8.6, 34110, 'Makoto Shinkai'],
#  ['The Intouchables', 2011, 8.6, 557965, 'Olivier Nakache'],
#  ['The Prestige', 2006, 8.5, 913152, 'Christopher Nolan'],
#  ['The Departed', 2006, 8.5, 937414, 'Martin Scorsese'],
#  ['The Dark Knight Rises', 2012, 8.5, 1222645, 'Christopher Nolan'],
#  ['Whiplash', 2014, 8.5, 477276, 'Damien Chazelle']]

# %% [markdown]
# # Q5
# ### Convert -ive numbers in a List to +ive

# %%
ls_num = [61, 72, -38, 73, 40, -17, 16, 69, 34, 59, 66, 27, 84, -21, 75]
ls_num
# Out:
# [61, 72, -38, 73, 40, -17, 16, 69, 34, 59, 66, 27, 84, -21, 75]

# %%
#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#--------Expected Output-----------
# Out:
# [61, 72, 38, 73, 40, 17, 16, 69, 34, 59, 66, 27, 84, 21, 75]
