# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ##  Python Programming Practice Set 05 (mini project) - Students Evaluation
# ### Overall Instructions:
# * This project requires you to work on Students examination scores information and perform evaluation to identify top ranking students
# * In terms of progression, the steps are : Re-organization --> Cleaning --> Extracting --> Processing --> Ranking
# * You are required to develop/test your solutions in a Jupyter Notebook
#
# ***
# ### Dos:
# * Under every question you are expected to write a User Defined Function with a specific name (mentioned in each question)
# * Further instructions/guidance is provided against each question.
# * **Closely observe the reference output shown against each question to test your code output (to know how close or off your solution is)**
# ***
# ### Dont's:
# * <font color='red'>**Use of Pandas/DataFrames, Numpy/Arrays and any other Library based/ or User defined Data Structures (taught outside the Python Programming Module) are not permitted in this Project**</font>
# </div>

# %% [markdown]
# ## Information to be used (without any alterations) for this project

# %%
raw_info = ['Class', 'Section', 'Rollno', 'Studentname', 'Gender', 'English', 'Mathematics', 'Science', 
            '8', 'A', '1', 'Neel Pittman', 'M', '34', '55', '39', '8', 'A', '2', 'Marnie Mohamed', 'F', '52', '43', '42',
            '8', 'B', '1', 'Mikaeel Estrada', 'M', '35', '44', '55', '8', 'B', '2', 'Bertha Obrien', 'F', '46', '30', '50', 
            '9', 'A', '1', 'Aryan Gray', 'M', '58', '59', '43', '9', 'A', '2', 'Eren Head', 'M', '59', '42', '51', 
            '9', 'B', '1', 'Pharrell Campbell', 'M', '56', '43', '54', '9', 'B', '2', 'Riaz Patrick', 'M', '56', '37', '55', 
            '10', 'A', '1', 'Britany Travers', 'F', '30', '57', '44','10', 'A', '2', 'Yuvaan Whittington', 'M', '53', '47', '54', 
            '10', 'B', '1', 'Naomi Walters', 'F', '54', '53', '47', '10', 'B', '2', 'Cassie Justice', 'M', '35', '36', '50']

# %% [markdown]
# ### Q1 - Write a function 'raw_to_nested_list', which takes the provided List 'raw_info' (of students exam scores) as an input and returns a Nested List where the information of each student is stored in sub-lists
# * You can assume that the below sequence of Eight Attributes repeat in the raw_info List:
#  * Class
#  * Section
#  * Rollno
#  * Studentname
#  * Gender
#  * English Score
#  * Mathematics Score
#  * Science Score

# %%
def raw_to_nested_list(input_list):
    #-------------Write your code here----------
    #-------------Write your code here----------
    #-------------Write your code here----------

# %% [markdown]
# #### _Function input for reference_

# %%
print(raw_info)
# Out:
# ['Class', 'Section', 'Rollno', 'Studentname', 'Gender', 'English', 'Mathematics', 'Science', '8', 'A', '1', 'Neel Pittman', 'M', '34', '55', '39', '8', 'A', '2', 'Marnie Mohamed', 'F', '52', '43', '42', '8', 'B', '1', 'Mikaeel Estrada', 'M', '35', '44', '55', '8', 'B', '2', 'Bertha Obrien', 'F', '46', '30', '50', '9', 'A', '1', 'Aryan Gray', 'M', '58', '59', '43', '9', 'A', '2', 'Eren Head', 'M', '59', '42', '51', '9', 'B', '1', 'Pharrell Campbell', 'M', '56', '43', '54', '9', 'B', '2', 'Riaz Patrick', 'M', '56', '37', '55', '10', 'A', '1', 'Britany Travers', 'F', '30', '57', '44', '10', 'A', '2', 'Yuvaan Whittington', 'M', '53', '47', '54', '10', 'B', '1', 'Naomi Walters', 'F', '54', '53', '47', '10', 'B', '2', 'Cassie Justice', 'M', '35', '36', '50']

# %% [markdown]
# #### _Function output for reference_

# %%
raw_to_nested_list(raw_info)
# Out:
# [['8', 'A', '1', 'Neel Pittman', 'M', '34', '55', '39'],
#  ['8', 'A', '2', 'Marnie Mohamed', 'F', '52', '43', '42'],
#  ['8', 'B', '1', 'Mikaeel Estrada', 'M', '35', '44', '55'],
#  ['8', 'B', '2', 'Bertha Obrien', 'F', '46', '30', '50'],
#  ['9', 'A', '1', 'Aryan Gray', 'M', '58', '59', '43'],
#  ['9', 'A', '2', 'Eren Head', 'M', '59', '42', '51'],
#  ['9', 'B', '1', 'Pharrell Campbell', 'M', '56', '43', '54'],
#  ['9', 'B', '2', 'Riaz Patrick', 'M', '56', '37', '55'],
#  ['10', 'A', '1', 'Britany Travers', 'F', '30', '57', '44'],
#  ['10', 'A', '2', 'Yuvaan Whittington', 'M', '53', '47', '54'],
#  ['10', 'B', '1', 'Naomi Walters', 'F', '54', '53', '47'],
#  ['10', 'B', '2', 'Cassie Justice', 'M', '35', '36', '50']]

# %% [markdown]
# ### Q2 - Write a function 'clean_nested_list', which takes a Nested List (of students exam scores) as input and returns its cleaned version where any Numbers showing as Strings are converted to Numbers

# %%
def clean_nested_list(unformatted_nested_list):
    #-------------Write your code here----------
    #-------------Write your code here----------
    #-------------Write your code here----------

# %% [markdown]
# #### _Function input for reference_

# %%
nested_list
# Out:
# [['8', 'A', '1', 'Neel Pittman', 'M', '34', '55', '39'],
#  ['8', 'A', '2', 'Marnie Mohamed', 'F', '52', '43', '42'],
#  ['8', 'B', '1', 'Mikaeel Estrada', 'M', '35', '44', '55'],
#  ['8', 'B', '2', 'Bertha Obrien', 'F', '46', '30', '50'],
#  ['9', 'A', '1', 'Aryan Gray', 'M', '58', '59', '43'],
#  ['9', 'A', '2', 'Eren Head', 'M', '59', '42', '51'],
#  ['9', 'B', '1', 'Pharrell Campbell', 'M', '56', '43', '54'],
#  ['9', 'B', '2', 'Riaz Patrick', 'M', '56', '37', '55'],
#  ['10', 'A', '1', 'Britany Travers', 'F', '30', '57', '44'],
#  ['10', 'A', '2', 'Yuvaan Whittington', 'M', '53', '47', '54'],
#  ['10', 'B', '1', 'Naomi Walters', 'F', '54', '53', '47'],
#  ['10', 'B', '2', 'Cassie Justice', 'M', '35', '36', '50']]

# %% [markdown]
# #### _Function output for reference_

# %%
clean_nested_list(nested_list)
# Out:
# [[8, 'A', 1, 'Neel Pittman', 'M', 34, 55, 39],
#  [8, 'A', 2, 'Marnie Mohamed', 'F', 52, 43, 42],
#  [8, 'B', 1, 'Mikaeel Estrada', 'M', 35, 44, 55],
#  [8, 'B', 2, 'Bertha Obrien', 'F', 46, 30, 50],
#  [9, 'A', 1, 'Aryan Gray', 'M', 58, 59, 43],
#  [9, 'A', 2, 'Eren Head', 'M', 59, 42, 51],
#  [9, 'B', 1, 'Pharrell Campbell', 'M', 56, 43, 54],
#  [9, 'B', 2, 'Riaz Patrick', 'M', 56, 37, 55],
#  [10, 'A', 1, 'Britany Travers', 'F', 30, 57, 44],
#  [10, 'A', 2, 'Yuvaan Whittington', 'M', 53, 47, 54],
#  [10, 'B', 1, 'Naomi Walters', 'F', 54, 53, 47],
#  [10, 'B', 2, 'Cassie Justice', 'M', 35, 36, 50]]

# %% [markdown]
# ### Q3 - Write a function 'create_nested_dict', which takes a Nested List (of students exam scores) as input and returns a Nested Dictionary that follows the structure: {Class : {Section : { Student Name : [Subject Marks] } } }
# * While developing the logic assume that Each class will have equal number of Sections

# %%
def create_nested_dict(formatted_nested_list):
    #-------------Write your code here----------
    #-------------Write your code here----------
    #-------------Write your code here----------

# %% [markdown]
# #### _Function input for reference_

# %%
nested_list
# Out:
# [[8, 'A', 1, 'Neel Pittman', 'M', 34, 55, 39],
#  [8, 'A', 2, 'Marnie Mohamed', 'F', 52, 43, 42],
#  [8, 'B', 1, 'Mikaeel Estrada', 'M', 35, 44, 55],
#  [8, 'B', 2, 'Bertha Obrien', 'F', 46, 30, 50],
#  [9, 'A', 1, 'Aryan Gray', 'M', 58, 59, 43],
#  [9, 'A', 2, 'Eren Head', 'M', 59, 42, 51],
#  [9, 'B', 1, 'Pharrell Campbell', 'M', 56, 43, 54],
#  [9, 'B', 2, 'Riaz Patrick', 'M', 56, 37, 55],
#  [10, 'A', 1, 'Britany Travers', 'F', 30, 57, 44],
#  [10, 'A', 2, 'Yuvaan Whittington', 'M', 53, 47, 54],
#  [10, 'B', 1, 'Naomi Walters', 'F', 54, 53, 47],
#  [10, 'B', 2, 'Cassie Justice', 'M', 35, 36, 50]]

# %% [markdown]
# #### _Function output for reference_

# %%
create_nested_dict(nested_list)
# Out:
# {8: {'A': {'Neel Pittman': [34, 55, 39], 'Marnie Mohamed': [52, 43, 42]},
#   'B': {'Mikaeel Estrada': [35, 44, 55], 'Bertha Obrien': [46, 30, 50]}},
#  9: {'A': {'Aryan Gray': [58, 59, 43], 'Eren Head': [59, 42, 51]},
#   'B': {'Pharrell Campbell': [56, 43, 54], 'Riaz Patrick': [56, 37, 55]}},
#  10: {'A': {'Britany Travers': [30, 57, 44],
#    'Yuvaan Whittington': [53, 47, 54]},
#   'B': {'Naomi Walters': [54, 53, 47], 'Cassie Justice': [35, 36, 50]}}}

# %% [markdown]
# ### Q4 - Write a Function 'show_student_scores' which takes the below Four Arguments as input and returns in a Dictionary the subject wise marks
# 1. Nested Dictionary (of students exam scores)
# 2. Class - C
# 3. Section - S
# 4. Student Name - N
#
# <font color=red>__For students not present in the Nested Dictionary, the function should print a message: 'Student Information provided is incorrect__</font>

# %%
def show_student_scores(nested_dict,C,S,N):
    #-------------Write your code here----------
    #-------------Write your code here----------
    #-------------Write your code here----------

# %% [markdown]
# #### _Function input for reference_

# %%
nested_dictionary
# Out:
# {8: {'A': {'Neel Pittman': [34, 55, 39], 'Marnie Mohamed': [52, 43, 42]},
#   'B': {'Mikaeel Estrada': [35, 44, 55], 'Bertha Obrien': [46, 30, 50]}},
#  9: {'A': {'Aryan Gray': [58, 59, 43], 'Eren Head': [59, 42, 51]},
#   'B': {'Pharrell Campbell': [56, 43, 54], 'Riaz Patrick': [56, 37, 55]}},
#  10: {'A': {'Britany Travers': [30, 57, 44],
#    'Yuvaan Whittington': [53, 47, 54]},
#   'B': {'Naomi Walters': [54, 53, 47], 'Cassie Justice': [35, 36, 50]}}}

# %% [markdown]
# #### _Function output for reference : scenario 1_

# %%
show_student_scores(nested_dictionary,10,'A','Britany Travers')
# Out:
# {'English': 30, 'Mathematics': 57, 'Science': 44}

# %% [markdown]
# #### _Function output for reference : scenario 2_

# %%
show_student_scores(nested_dictionary,10,'B','Random Name')
# Out:
# Student record does not exists

# %% [markdown]
# ### Q5 - Write a function 'get_total_scores', which takes a Nested Dictionary (of students exam scores) as input and overwrites it, such that the individual subject scores (a list) is replaced with the Total scores (sum of these three subjects scores)

# %%
def get_total_scores(nested_dict):
    #-------------Write your code here----------
    #-------------Write your code here----------
    #-------------Write your code here----------

# %% [markdown]
# #### _Function input for reference_

# %%
nested_dictionary
# Out:
# {8: {'A': {'Neel Pittman': [34, 55, 39], 'Marnie Mohamed': [52, 43, 42]},
#   'B': {'Mikaeel Estrada': [35, 44, 55], 'Bertha Obrien': [46, 30, 50]}},
#  9: {'A': {'Aryan Gray': [58, 59, 43], 'Eren Head': [59, 42, 51]},
#   'B': {'Pharrell Campbell': [56, 43, 54], 'Riaz Patrick': [56, 37, 55]}},
#  10: {'A': {'Britany Travers': [30, 57, 44],
#    'Yuvaan Whittington': [53, 47, 54]},
#   'B': {'Naomi Walters': [54, 53, 47], 'Cassie Justice': [35, 36, 50]}}}

# %% [markdown]
# #### _Function output for reference_

# %%
get_total_scores(nested_dictionary)
# Out:
# {8: {'A': {'Neel Pittman': 128, 'Marnie Mohamed': 137},
#   'B': {'Mikaeel Estrada': 134, 'Bertha Obrien': 126}},
#  9: {'A': {'Aryan Gray': 160, 'Eren Head': 152},
#   'B': {'Pharrell Campbell': 153, 'Riaz Patrick': 148}},
#  10: {'A': {'Britany Travers': 131, 'Yuvaan Whittington': 154},
#   'B': {'Naomi Walters': 154, 'Cassie Justice': 121}}}

# %% [markdown]
# ### Q6 - Write a function 'get_max_scores', which takes a Nested Dictionary (of students exam scores) as input and returns another Nested Dictionary that stores for each Class, the Max of Total Scores
# * For the Dictionary to be created, the 'Key' and 'Value' parts will be Class and Max of Total Scores respectively
# * E.g. : {8: 130, 9: 140, 10: 155}, where 130 is the Highest value of Total Scores for Class 8 Students, and so on...

# %%
def get_max_scores(nested_dict):
    #-------------Write your code here----------
    #-------------Write your code here----------
    #-------------Write your code here----------

# %% [markdown]
# #### _Function input for reference_

# %%
nested_dictionary
# Out:
# {8: {'A': {'Neel Pittman': 128, 'Marnie Mohamed': 137},
#   'B': {'Mikaeel Estrada': 134, 'Bertha Obrien': 126}},
#  9: {'A': {'Aryan Gray': 160, 'Eren Head': 152},
#   'B': {'Pharrell Campbell': 153, 'Riaz Patrick': 148}},
#  10: {'A': {'Britany Travers': 131, 'Yuvaan Whittington': 154},
#   'B': {'Naomi Walters': 154, 'Cassie Justice': 121}}}

# %% [markdown]
# #### _Function output for reference_

# %%
get_max_scores(nested_dictionary)
# Out:
# {8: 137, 9: 160, 10: 154}

# %% [markdown]
# ### Q7 - Write a function 'get_class_toppers' that takes the below Two inputs and returns a new Dictionary with Class wise Top Scorers (toppers)
# * **Input 1 - Nested Dictionary with Total scores of Students**
# * **Input 2 - Dictionary with Class wise Max of Total scores**
# ***
# * **Output Dictionary - the 'Key' part will be the Class and the 'Value' part will be a List, which stores the name(s) of Top Scorer(s)**
# * E.g. of output dictionary - {8: ['John Smith','Max Payne'], 9: ['Lara Croft','Mario','Nintendo'], 10: ['Luigi']}, where :
#  * John Smith and Max Payne are the Top scorers for Class 8
#  * Lara Croft, Mario and Nintendo are the Top scorers for Class 9, and
#  * Luigi is the Top scorer for Class 10

# %%
def get_class_toppers(nested_dict,max_scores_dict):
    #-------------Write your code here----------
    #-------------Write your code here----------
    #-------------Write your code here----------

# %% [markdown]
# #### _Function inputs for reference_

# %%
nested_dictionary
# Out:
# {8: {'A': {'Neel Pittman': 128, 'Marnie Mohamed': 137},
#   'B': {'Mikaeel Estrada': 134, 'Bertha Obrien': 126}},
#  9: {'A': {'Aryan Gray': 160, 'Eren Head': 152},
#   'B': {'Pharrell Campbell': 153, 'Riaz Patrick': 148}},
#  10: {'A': {'Britany Travers': 131, 'Yuvaan Whittington': 154},
#   'B': {'Naomi Walters': 154, 'Cassie Justice': 121}}}

# %%
max_scores_dict
# Out:
# {8: 137, 9: 160, 10: 154}

# %% [markdown]
# #### _Function output for reference_

# %%
get_class_toppers(nested_dictionary,max_scores_dict)
# Out:
# {8: ['Marnie Mohamed'],
#  9: ['Aryan Gray'],
#  10: ['Yuvaan Whittington', 'Naomi Walters']}
