# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravleo40/Python-Programming-Course/blob/main/Practice_Questions_Set_01%20New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Set 01**
# * For all the questions you can self-check whether your solution creates the right output (or not)
# * Your code solution should generate an output similar to the ones shown in Cells 'Expected output' against every question. __Avoid running these cells as it will overwrite the displayed output__

# %% [markdown]
# ## **Q1**
# ### Two variables x and y are created to store integer values. Use Three different approaches to swap their values.
# 1. Approach 1: Swap values using a third variable (let’s say z)
# 2. Approach 2: Swap values without using any other variable
# 3. Approach 3 : Use Tuple unpacking
#
# _See the below cell and the expected output for reference_

# %%
x=100
y=5
print("Original value of x is :",x)
print("Original value of y is :",y)

#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

print("New value of x is :",x)
print("New value of y is :",y)

# %%
#--------Expected Output-----------
# Out:
# Original value of x is : 100
# Original value of y is : 5
# New value of x is : 100
# New value of y is : 5

# %% [markdown]
# ## **Additional information on print() function:**
# ### Multiple statements can be passed in the same instance of print(). Apply learnings from this to solve Q# 2

# %%
#---------print() function example 1------
print('A coin has Two sides','Heads','and','Tails')
# Out:
# A coin has Two sides Heads and Tails

# %%
#---------print() function example 2------
coin = 2
dice = 6

#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#--------Expected Output-----------
# Out:
# A coin has 2 outcomes
# A dice has 6 outcomes

# %% [markdown]
# ## **Q2**
#
# ### Declare Two variables x and y and write code lines to display the following output

# %%
x = 91
y = 7

#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#--------Expected Output-----------
# Out:
# Sum of 91 and 7 is : 98
# Difference of 91 and 7 is : 84
# Product of 91 and 7 is : 637
# Ratio of 91 and 7 is : 13.0

# %% [markdown]
# ## **Q3**

# %% [markdown]
# ### Write a short code which prints Tuples with the following pattern (refer expected output) ?
# #### Hint : Avoid using any 'for loops' or 'user defined functions'. Your code should use only One Variable. Thus for generating a new Tuple, you are required to change just one value

# %%
#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#--------Expected Output - example 1-----------
# Out:
# (2, 4, 8, 16, 32, 64, 128, 256, 512, 1024)

# %%
#--------Expected Output - example 2-----------
# Out:
# (3, 9, 27, 81, 243, 729, 2187, 6561, 19683, 59049)

# %%
#--------Expected Output - example 3-----------
# Out:
# (4, 16, 64, 256, 1024, 4096, 16384, 65536, 262144, 1048576)
