# %% [markdown]
# # Practice Set 04
# * For all the questions you can self-check whether your solution creates the right output (or not)
# * Your code solution should generate an output similar to the 'Expected output' shown against every question. __Avoid running this cell as it will overwrite the displayed output__

# %%
import random

# %% [markdown]
# # Q1
#
# * You are provided with a nested list 'movies_info'.
# * By taking a movie director's name as 'User input', display all movies (the entire sub-lists with movies information) directed by this particular director.
# * Also print the number of movies directed (as shown in the expected output below)

# %%
movies_info = [['Pulp Fiction', 1994, 8.9, 1828915, 'Quentin Tarantino'],
    ['The Shawshank Redemption', 1994, 9.3, 2442565, 'Frank Darabont'],
    ['The Godfather', 1972, 9.2, 1645990, 'Francis Ford Coppola'],
    ['Fight Club', 1999, 8.8, 1906665, 'David Fincher'],
    ['Forrest Gump', 1994, 8.8, 1908883, 'Robert Zemeckis'],
    ['The Matrix', 1999, 8.7, 1761722, 'Lana and Lilly Wachowski'],
    ['The Silence of the Lambs', 1991, 8.6, 1301892, 'Jonathan Demme'],
    ['Gladiator', 2000, 8.5, 1389712, 'Ridley Scott'],
    ['The Social Network', 2010, 7.7, 654824, 'David Fincher'],
    ['The Grand Budapest Hotel', 2014, 8.1, 751735, 'Wes Anderson'],
    ['Django Unchained', 2012, 8.4, 1453153, 'Quentin Tarantino'],
    ['The Green Mile', 1999, 8.6, 1153082, 'Frank Darabont'],
    ['Apocalypse Now', 1979, 8.4, 593227, 'Francis Ford Coppola'],
    ['Se7en', 1995, 8.6, 1518612, 'David Fincher'],
    ['Cast Away', 2000, 7.8, 562802, 'Robert Zemeckis'],
    ['The Matrix Reloaded', 2003, 7.2, 521867, 'Lana and Lilly Wachowski'],
    ['The Manchurian Candidate', 2004, 6.6, 104516, 'Jonathan Demme'],
    ['Kingdom of Heaven', 2005, 7.2, 263740, 'Ridley Scott'],
    ['Gone Girl', 2014, 8.1, 886902, 'David Fincher'],
    ['Moonrise Kingdom', 2012, 7.8, 363125, 'Wes Anderson'],
    ['The Usual Suspects', 1995, 8.5, 1016113, 'Bryan Singer'],
    ['Blade Runner', 1982, 8.1, 721688, 'Ridley Scott'],
    ['The Godfather: Part II', 1974, 9.0, 1149024, 'Francis Ford Coppola'],
    ['The Revenant', 2015, 8.0, 743775, 'Alejandro G. Iñárritu'],
    ['Eternal Sunshine of the Spotless Mind', 2004, 8.3, 939660, 'Michel Gondry'],
    ['The Lion King', 1994, 8.5, 968426, 'Roger Allers, Rob Minkoff'],
    ['The Shining', 1980, 8.4, 924264, 'Stanley Kubrick'],
    ['The Departed', 2006, 8.5, 937414, 'Martin Scorsese'],
    ['The Incredibles', 2004, 8.0, 678229, 'Brad Bird'],
    ['The Dark Knight Rises', 2012, 8.5, 1222645, 'Christopher Nolan']]

#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#--------Expected Output-----------
# Out:
# Enter the Director Name :Michel Gondry
#
# ['Eternal Sunshine of the Spotless Mind', 2004, 8.3, 939660, 'Michel Gondry']
#
# Number of movies directed by 'Michel Gondry' : 1

# %% [markdown]
# # Q2
# ### Using the below list 'all_words', create a Dictionary where Keys are the individual words and values are their Index values in the original list

# %%
all_words = ['bad', 'cat', 'dog', 'fast', 'good', 'horse', 'is', 'slow', 'snail', 'the']

#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#----------------Expected output------------
# Out:
# {'bad': 0,
#  'cat': 1,
#  'dog': 2,
#  'fast': 3,
#  'good': 4,
#  'horse': 5,
#  'is': 6,
#  'slow': 7,
#  'snail': 8,
#  'the': 9}

# %% [markdown]
# # Q3
# ### Using the lists 'breakfast_items' and 'days' defined below , Create a dictionary 'orders' (refer expected output). The breakfast items can be randomly picked without repetition

# %%
breakfast_items=['Coffee','Butter Toast','Butter Milk','Bread Jam','Egg','Muffin','Sandwich','Toast','Boiled Egg','Scrambled Eggs',
                'Fruit Juice','Milkshake','Waffles','Corn Flakes','Cereal','Fruit','Bacon Eggs','Grilled Sandwich',
                'Bagel','Pan Cake','Baked Beans','Fried Eggs','Sausage','Tea','Sprouts','Banista','Pastries','Cornetto']
days=['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#----------------Expected output------------
# Out:
# {'Mon': ['Sandwich', 'Boiled Egg', 'Cornetto'],
#  'Tue': ['Egg', 'Sandwich', 'Sausage'],
#  'Wed': ['Muffin', 'Cereal', 'Boiled Egg'],
#  'Thu': ['Butter Milk', 'Butter Toast', 'Fried Eggs'],
#  'Fri': ['Egg', 'Fruit', 'Fried Eggs'],
#  'Sat': ['Bread Jam', 'Scrambled Eggs', 'Baked Beans'],
#  'Sun': ['Cornetto', 'Fruit Juice', 'Fried Eggs']}

# %% [markdown]
# ## Run the following code to create a Dictionary 'sscores'. Attempt Q4 to Q7 based on the dictionaries 'sscores'

# %%
ls_names=['Emma','Silvia','Bryan','Hannah','John','Kim','Martha','Kevin','Bob','Mary','Ben','Alex',
          'Tim','Don','Ken','Roger','Joan','Stan','Peggy','Bert','Rick','Oliver','Noah','Oscar',
          'Evelyn','Florence','Theo','Isabella','Lily','Ava']
names=random.sample(ls_names,10)
scores=[ [random.randint(50,100) for i in range(5)] for i in range(10)]
sscores=dict(zip(names,scores))
sscores
# Out:
# {'Ken': [67, 70, 59, 74, 69],
#  'Joan': [71, 54, 96, 55, 98],
#  'John': [82, 94, 92, 96, 72],
#  'Martha': [79, 78, 53, 86, 68],
#  'Theo': [83, 86, 94, 54, 97],
#  'Rick': [62, 81, 75, 58, 84],
#  'Silvia': [92, 59, 99, 90, 97],
#  'Ava': [97, 63, 72, 61, 62],
#  'Ben': [52, 82, 84, 75, 98],
#  'Hannah': [87, 100, 66, 95, 62]}

# %% [markdown]
# # Q4
# ### Create a new dictionary with these Student names and their average scores (across Five subjects)

# %%
#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#---------Expected Output-------------
# Out:
# {'Ken': 67.8,
#  'Joan': 74.8,
#  'John': 87.2,
#  'Martha': 72.8,
#  'Theo': 82.8,
#  'Rick': 72.0,
#  'Silvia': 87.4,
#  'Ava': 71.0,
#  'Ben': 78.2,
#  'Hannah': 82.0}

# %% [markdown]
# # Q5
# ### Add total scores for each student to the dictionary

# %% [markdown]
# __Example:__ {'Roger': [90, 62, 86, 72, 60, __370__],...}

# %%
#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#---------Expected Output-------------
# Out:
# {'Ken': [67, 70, 59, 74, 69, 339],
#  'Joan': [71, 54, 96, 55, 98, 374],
#  'John': [82, 94, 92, 96, 72, 436],
#  'Martha': [79, 78, 53, 86, 68, 364],
#  'Theo': [83, 86, 94, 54, 97, 414],
#  'Rick': [62, 81, 75, 58, 84, 360],
#  'Silvia': [92, 59, 99, 90, 97, 437],
#  'Ava': [97, 63, 72, 61, 62, 355],
#  'Ben': [52, 82, 84, 75, 98, 391],
#  'Hannah': [87, 100, 66, 95, 62, 410]}

# %% [markdown]
# # Q6
# ### Increment the Fifth subject scores by 5 numbers (such that the resulting score <=100). Use the original 'sscores' dictionary for this operation (without the totals)

# %%
ls_names=['Emma','Silvia','Bryan','Hannah','John','Kim','Martha','Kevin','Bob','Mary','Ben','Alex',
          'Tim','Don','Ken','Roger','Joan','Stan','Peggy','Bert','Rick','Oliver','Noah','Oscar',
          'Evelyn','Florence','Theo','Isabella','Lily','Ava']
names=random.sample(ls_names,10)
scores=[ [random.randint(50,100) for i in range(5)] for i in range(10)]
sscores=dict(zip(names,scores))
sscores
# Out:
# {'Don': [77, 83, 51, 63, 71],
#  'Oliver': [60, 50, 61, 100, 51],
#  'Ava': [56, 53, 65, 78, 62],
#  'Stan': [79, 99, 50, 68, 60],
#  'Bryan': [91, 61, 72, 55, 97],
#  'Hannah': [87, 84, 67, 92, 91],
#  'Mary': [95, 87, 96, 65, 65],
#  'Evelyn': [82, 69, 65, 87, 98],
#  'Ben': [94, 75, 95, 57, 88],
#  'Martha': [55, 71, 65, 60, 99]}

# %%
#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#---------Expected Output-------------
# Out:
# {'Don': [77, 83, 51, 63, 76],
#  'Oliver': [60, 50, 61, 100, 56],
#  'Ava': [56, 53, 65, 78, 67],
#  'Stan': [79, 99, 50, 68, 65],
#  'Bryan': [91, 61, 72, 55, 100],
#  'Hannah': [87, 84, 67, 92, 96],
#  'Mary': [95, 87, 96, 65, 70],
#  'Evelyn': [82, 69, 65, 87, 100],
#  'Ben': [94, 75, 95, 57, 93],
#  'Martha': [55, 71, 65, 60, 100]}

# %% [markdown]
# # Q7
# ### Using just List Comprehension find the Max scores for each subject. Use the original dictionary 'sscores' for this operation

# %%
ls_names=['Emma','Silvia','Bryan','Hannah','John','Kim','Martha','Kevin','Bob','Mary','Ben','Alex',
          'Tim','Don','Ken','Roger','Joan','Stan','Peggy','Bert','Rick','Oliver','Noah','Oscar',
          'Evelyn','Florence','Theo','Isabella','Lily','Ava']
names=random.sample(ls_names,10)
scores=[ [random.randint(50,100) for i in range(5)] for i in range(10)]
sscores=dict(zip(names,scores))
sscores
# Out:
# {'Martha': [68, 56, 99, 99, 81],
#  'Mary': [89, 59, 56, 96, 56],
#  'Bob': [81, 94, 94, 98, 60],
#  'Bert': [82, 95, 52, 75, 58],
#  'Tim': [98, 89, 95, 65, 97],
#  'Peggy': [62, 94, 53, 98, 51],
#  'Oliver': [87, 61, 64, 79, 71],
#  'Silvia': [56, 100, 67, 50, 66],
#  'Ava': [67, 83, 62, 87, 98],
#  'Joan': [56, 57, 63, 99, 72]}

# %%
#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#---------Expected Output-------------
# Out:
# [98, 100, 99, 99, 98]

# %% [markdown]
# # Q8
# ### You are given with a List of employee IDs of existing employees in a startup company. Two new employees have joined recently. Generate their employee IDs which are +1 of the existing ID with the highest number value. Display the List of employee IDs for every addition.

# %%
empids = ['E34', 'E54', 'E43', 'E12', 'E37', 'E53']
empids
# Out:
# ['E34', 'E54', 'E43', 'E12', 'E37', 'E53']

# %%
#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %% [markdown]
# #### Employee ID list after adding one new employee

# %%
#--------Expected Output-----------
# Out:
# ['E34', 'E54', 'E43', 'E12', 'E37', 'E53', 'E55']

# %% [markdown]
# #### Employee ID list after adding the second new employee

# %%
#--------Expected Output-----------
# Out:
# ['E34', 'E54', 'E43', 'E12', 'E37', 'E53', 'E55', 'E56']

# %% [markdown]
# # Q9
# ### You are given with a List consisting of names of multiple log files. Create a new list (using just LIST COMPREHENSION) to store the files pertaining to the year >= 2020

# %%
logfiles = ['logfile_ugxof_2020', 'logfile_qbgzc_2020', 'logfile_nbrpm_2021', 'logfile_fayvc_2015', 'logfile_lgyrk_2014', 'logfile_xanhz_2015', 'logfile_phaud_2020', 'logfile_bcsoa_2012', 'logfile_mqylv_2020', 'logfile_xcjpw_2017', 'logfile_jvoyl_2016', 'logfile_qmsft_2014', 'logfile_qiokp_2021', 'logfile_wzihp_2020', 'logfile_ratlm_2016']

# %%
#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#--------Expected Output-----------
# Out:
# ['logfile_ugxof_2020',
#  'logfile_qbgzc_2020',
#  'logfile_nbrpm_2021',
#  'logfile_phaud_2020',
#  'logfile_mqylv_2020',
#  'logfile_qiokp_2021',
#  'logfile_wzihp_2020']

# %% [markdown]
# # Q10
# ### Separate the ID and Domain part of the multiple email-ids and place in separated pieces in Nested Tuples

# %%
random_emails = ['natoques@semper.edu',
    'varius@nisl.org',
    'lorem@euismodin.org',
    'randomuser1@gmail.com',
    'testuser@yahoo.com',
    'exampleuser@hotmail.com',
    'user123@example.com',
    'emailuser@company.org',
    'john.doe@gmail.com',
    'alice.smith@yahoo.com']

# %%
#--------Write your code here-----------
#--------Write your code here-----------
#--------Write your code here-----------

# %%
#--------Expected Output-----------
# Out:
# (('natoques', 'semper.edu'),
#  ('varius', 'nisl.org'),
#  ('lorem', 'euismodin.org'),
#  ('randomuser1', 'gmail.com'),
#  ('testuser', 'yahoo.com'),
#  ('exampleuser', 'hotmail.com'),
#  ('user123', 'example.com'),
#  ('emailuser', 'company.org'),
#  ('john.doe', 'gmail.com'),
#  ('alice.smith', 'yahoo.com'))
