# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravleo40/Python-Programming-Course/blob/main/02_type()_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **This notebook outlines how Python's `type()` function works and the different contexts in which it can be used**

# %% [markdown]
# ## **01 Working**
# * The primary purpose of the `type()` function in Python is to determine and return the type of a given object.
# * If you are unsure whether a given variable is integer, float, boolean, string or let's say a Data Structure (`List`, `Tuple`, etc.), you can use the `type()` function on the variable name
# * A better knowledge of the 'type of the object' helps us apply appropriate operations on it
# * It is useful to debug and understand the behavior of different variables and expressions

# %% [markdown]
# ## **02 Use**

# %% [markdown]
# #### **Determining Data Types of values**

# %%
type('Hello World')
# Out:
# str

# %%
type('1000')
# Out:
# str

# %%
type(100)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type(4.56)
# Out:
# float

# %%
type(10+9j)
# Out:
# complex

# %% [markdown]
# #### **Determining Data Types expression outputs**

# %%
print(99 + True)
type(99 + True)
# Out:
# 100
# int

# %%
print(100/10)
type(100/10)
# Out:
# 10.0
# float

# %%
print(7 + 3.5)
type(7 + 3.5)
# Out:
# 10.5
# float

# %% [markdown]
# #### **Checking Type of Data Structures and other entities**
# * **Note :** Feel free to use `type()` to inspect data structures and other entities as they are introduced in the later modules.

# %%
nums = [1,2,3,4]
type(nums)
# Out:
# list

# %%
letters = ('A','B','C')
type(letters)
# Out:
# tuple

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
type(dir)
# Out:
# builtin_function_or_method

# %% [markdown]
# #### **Comparing `type()` function output against a criteria**
# * **Comparisons like below can be valuable for executing operations based on conditions.**
# * **Note :** These comparisons are particularly useful for conditional operations, which will be explored further in the later modules

# %%
type(100) == int
# Out:
# True

# %%
type(3.45) == int
# Out:
# False

# %%
type(10 + 2.9) == float
# Out:
# True

# %%
type(10>7) == bool
# Out:
# True

# %%
type(10!=7) == bool
# Out:
# True

# %%
type('Hi'*2) == str
# Out:
# True

# %% [markdown]
# ## **End of Document**
