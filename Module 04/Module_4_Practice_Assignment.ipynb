# %% [markdown]
#  # Module 4: Ungraded Practice Assignment
# Welcome to your practice assignment for Module 4! In this notebook, we will practice generating lists, finding list information, accessing elements, using list methods, and combining lists.
#
# **Instructions:**
# *   Read the text in the markdown cells carefully.
# *   Write your Python code in the empty code cells below each question.
# *   To run a code cell, click the "Play" button on the left or press `Shift + Enter`.
# *   *Reminder: We are not using built-in display functions yet. To see the value of a variable or the result of an operation, simply write the variable name on the very last line of the code cell.*

# %% [markdown]
# ### Q1 - Generate Match Fixtures
#
# ### **Write a Python program that generates and prints Fixtures for the upcoming Cricket Tournament**
#
# * Note that the List `Teams` is already defined for you. Thus avoid assigning your own values to it in your solution
# * Assume the List `Teams` to have at least Two names
# * **Avoid instances where the same Team name appears twice, e.g., Team 1 vs. Team 1**
# * Note: Ensure that your solution can handle varying lengths of the List `Teams`
# * **Important: Use only Python concepts that have been taught up until this module.**
#
#
# ### Expected output for reference
# For the below value of list `Teams`
# ```
# Teams = ['Team 1','Team 2','Team 3']
# ```
# your program should print
# ```
# Team 1 vs. Team 2
# Team 1 vs. Team 3
# Team 2 vs. Team 1
# Team 2 vs. Team 3
# Team 3 vs. Team 1
# Team 3 vs. Team 2
# ```

# %%
Teams = ['Team 1','Team 2','Team 3']
# Write your code here

# %% [markdown]
# ### Q2 - Check Special Characters in Password
#
# ### **Write a Python program that helps users set up their account password by checking for restricted special characters and giving a heads-up if the password needs to be changed.**
# * For this exercise you are provided with a string `password` and a List `restricted_chars`
# * If a restricted character (e.g., %) is found in the user password, then your program should print `Password contains a forbidden character '%'` and stop further checks.
# * If no restricted character is found in the user password, then your program should print `"Password is acceptable."`
# * Hint : You can apply 'Membership' operation on a string value. Refer the below code example:
#     ```
#     '@' in 'email@domain'    # returns True
#     '*' in 'email@domain'    # returns False
#     ```
# * **Important: Use only Python concepts that have been taught up until this module.**
#
#
# ### Expected output for reference
#
#  * Example 01 : For the below values of `password` and `restricted_chars`:
#     ```python
#     password = "SecureP@ssword2024"
#     restricted_chars = ['*', '^', '?', '~', '=']
#     ```
#     your program should print
#     ```
#     Password is acceptable.
#     ```
#  * Example 02 : For the below values of `password` and `restricted_chars`:
#     ```python
#     password = "Secure*Pssword^2024"
#     restricted_chars = ['*', '^', '?', '~', '=']
#     ```
#     your program should print
#     ```
#     Password contains a forbidden character `*`
#     ```

# %%
password = "SecureP@ssword2024"
restricted_chars = ['*', '^', '?', '~', '=']
# Write your code here

# %% [markdown]
# ### Q3 - Count bulk orders
#
# ### **Write a Python program that takes a list called `orders` and prints the number of bulk orders in it (orders with a quantity of 100 or more)**
#
# * Note that the variable `orders` is already defined for you. Thus avoid assigning your own value to it in your solution
# * Note: Ensure that your solution handles lists of varying lengths
#
# ### Expected output for Reference
# For the below value of `orders`
# ```
# orders = [73, 88, 106, 77, 79, 72, 104, 87, 99, 114]
# ```
# your solution should return
# ```
# 3
# ```

# %%
orders = [73, 88, 106, 77, 79, 72, 104, 87, 99, 114]
# Write your code here

# %% [markdown]
# ### Q4 - Assign grades based on a Score
#
# ### **Write a Python program to assign a grade based on a student's score stored in a variable `score` with the following criteria:**
# * Grading Criteria
#  * 95 or above: A+
#  * 87 to 94: A
#  * 78 to 86: B
#  * 65 to 77: C
#  * 50 to 64: D
#  * Below 50: Re-Attempt
# * Note that the variable `score` is already defined for you. Thus avoid assigning your own value to it in your solution
#
# ### Expected output for Reference
# For the below value of `orders`
# ```
# score = 90
# ```
# your solution should return
# ```
# A
# ```

# %%
x = 90
# Write your code here

# %% [markdown]
# ### Q5 - Simulate `n` coin tosses
#
# ### **You are required to simulate a coin toss experiment by tossing an unbiased coin `n` times, where `n` is a positive integer provided to you. Record the outcome of each toss, noting whether it was `Heads` or `Tails`. Store these outcomes in a list named `outcomes` and print the list.**
#
# * Note: Ensure that your solution handles various values of `n`
#
# ### Expected output for Reference
# * Example 01 - For n = 5 your solution should return an output similar to the below List
#
#   ```
#   ['Heads', 'Tails', 'Tails', 'Heads', 'Heads']
#   ```
#
# * Example 02 - For n = 3 your solution should return an output similar to the below List
#
#   ```
#   ['Tails', 'Tails', 'Heads']
#   ```

# %%
n = 7
# Write your code here

# %% [markdown]
# ### Q6 - Shuffle Breakfast Items for Each Day
#
# ### **You are provided with a Nested list `breakfast_schedule`, that contains breakfast items for each day of the week. Your task is to write a Python program that shuffles the items for each day**
# * Note: Ensure that your solution is be able to handle nested lists of different sizes (.i.e., both number of sub-lists and the number of items in the sub-lists)
#
# ### Expected output for Reference
# For the below provided nested list of breakfast items
# ```
# breakfast_schedule = [['Pancakes', 'Idli',A 'Croissant'],
#                       ['Bagel', 'Dosa', 'Muffin'],
#                       ['Omelette', 'Upma', 'Toast'],
#                       ['French Toast', 'Paratha', 'Scone'],
#                       ['Waffles', 'Poha', 'English Muffin'],
#                       ['Cereal', 'Chole Bhature', 'Brioche'],
#                       ['English Breakfast', 'Aloo Paratha', 'Crumpet']]
# ```
# your solution should return an output similar to the below List
#
# ```
# [['Idli', 'Croissant', 'Pancakes'],
#  ['Dosa', 'Muffin', 'Bagel'],
#  ['Omelette', 'Upma', 'Toast'],
#  ['French Toast', 'Scone', 'Paratha'],
#  ['Waffles', 'Poha', 'English Muffin'],
#  ['Cereal', 'Chole Bhature', 'Brioche'],
#  ['English Breakfast', 'Crumpet', 'Aloo Paratha']]
# ```

# %%
breakfast_schedule = [['Pancakes', 'Idli', 'Croissant'],
                      ['Bagel', 'Dosa', 'Muffin'],
                      ['Omelette', 'Upma', 'Toast'],
                      ['English Breakfast', 'Aloo Paratha', 'Crumpet']]

# Write your code here
