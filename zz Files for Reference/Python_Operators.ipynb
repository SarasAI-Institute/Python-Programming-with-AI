# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravleo40/Python-Programming-Course/blob/main/Python_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Arithmetic Operators**
#
#
#   Symbol |   Description                    |   Code Example     | Code Output
# :--------|:---------------------------------|:-------------------|:-----------
#     +    | Addition                         |  `print(10 + 2)`   |  `12`
#     -    | Subtraction                      |  `print(8 - 4)`    |   `4`
#     *    | Multiplication                   |  `print(7 * 5)`    |  `35`
#     /    | Division                         |  `print(10 / 2)`   |  `5.0`
#     %    | Modulus (returns remainder)      |  `print(9 % 4)`    |  `1`
#    //    | Floor Division (return quotient) |  `print(27 // 5)`  |  `5`
#   \*\*   | Exponentiation                   |  `print(2 ** 3)`   |   `8`

# %% [markdown]
# ## **Comparison Operators**
#
#
#   Symbol |   Description          |   Code Example     | Code Output
# :--------|:-----------------------|:-------------------|:-----------
#   >      | Greater than           |  `print(10 > 2)`   |  `True`
#   <      | Less than              |  `print(8 < 4)`    |   `False`
#   >=     | Greater than equal to  |  `print(7 >= 5)`   |  `True`
#   <=     | Less than equal to     |  `print(10 <= 2)`  |  `False`
#   ==     | Equal to               |  `print(9 == 4)`   |  `False`
#   !=     | Not Equal to           |  `print(27 != 5)`  |  `True`

# %% [markdown]
# ## **Assignment Operators**
#
#
#   <font size="3"> Symbol |<font size="3"> Description | <font size="3">Code Example | <font size="3"> Code Output
# :--------|:--------------|:----------------------------------|:-----------
#   =      | <font size="3"> Assigns the value or expression output on RHS to the variable name on LHS <br><br> | <font size="4"> `x = 5`<br>`print(x)`|  `5`
#   <br>
#   +=     | <font size="3">Overwrites the earlier value of x by adding the specified value <br><br> e.g., `x += 10` is same as `x = x + 10`  | <font size="4"> `x=5` <br> `x +=10` <br> `print(x)`|   `15`
#   <br>
#   -=     | <font size="3">Overwrites the earlier value of x by subtracting the specified value <br><br> e.g., `x -= 10` is same as `x = x - 10`     | <font size="4"> `x=20` <br> `x -=6` <br> `print(x)`|  `14`
#   <br>
#   \*=    |<font size="3">Overwrites the earlier value of x by multiplying the specified value <br><br> e.g., `x *= 10` is same as `x = x * 10`  | <font size="4"> `x=7` <br> `x *=2` <br> `print(x)`|  `14`
#   <br>
#   \/=    |<font size="3">Overwrites the earlier value of x by dividing the specified value <br><br> e.g., `x /= 10` is same as `x = x / 10`| <font size="4"> `x=50` <br> `print(x /=10)` <br> `print(x)`|  `5`
