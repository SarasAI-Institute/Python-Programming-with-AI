# %% [markdown]
# <div class="alert alert-block alert-warning" style="margin-bottom: 10px;">
#
# Before submitting this assignment, please ensure everything runs as expected.
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE".
#
# **Mandatory Step for Autograding:**
# You must provide your Name and Email ID in the designated cell below. **This information MUST be entered in ALL CAPITAL LETTERS.** This is a compulsory requirement; failure to format your details exactly as requested will cause the autograding system to fail, and your assignment will not be evaluated.
#
# </div>

# %%
NAME = ""
EMAIL_ID = ""

# %% [markdown]
# <div class="alert alert-block alert-warning" style="margin-bottom: 10px;">
#     <h4 style="margin-top: 0px;"><b>Important Instructions for Grading</b></h4>
#     <p style="margin-bottom: 0px;">Please read all the instructions carefully before starting. These instructions apply to the entire notebook. Following them will help your notebook get graded correctly.
#         Please note the color coding used in this notebook: <b>Yellow cells</b> contain general instructions and guidelines, while <b>Blue cells</b> contain the actual problem statements and cells are locked as read-only to ensure the autograder functions correctly. Do not attempt to unlock or bypass these restrictions.</li>
#     </p>
# </div>
#
# <div class="alert alert-block alert-warning" style="margin-bottom: 10px;">
#     <ul style="line-height: 1.8; margin-bottom: 0px;">
#         <li><b>Instruction 01:</b> Please add your name and email in the designated cell at the top of the notebook before you begin.</li>
#         <li><b>Instruction 02:</b> Do not delete this instruction cell, and do not delete the cell directly above it.</li>
#         <li><b>Instruction 03:</b> Do not <b>make any changes</b> to the notebook, except where you are asked to write your solution code.</li>
#         <li><b>Instruction 04:</b> Write your solution code <b>only</b> in the cells marked as shown below:
#     <br><br>
#     <code># ------------- Solution cell for Problem -------------</code><br>
#     <br>
#
# </li>
#         <li><b>Instruction 05:</b> For each question in this assignment, the required variables have already been defined for you with values that are hidden from you. Your task is to use these variables in your solution; <b>do not create or assign values to them in this notebook</b>.
#
# If you want to test your solution with different values, you can do so in a **separate Google Colab notebook, Jupyter notebook, or any other IDE**. You may assign your own values there and test your code with different inputs to make sure it works correctly.
#
# Once you are satisfied with your solution, copy the **final code only** into the appropriate **Solution cell** in this notebook. In the Solution cell, use the variable names provided in each question exactly as given, without declaring or assigning any values to them.
#
# </li>
#         <li><b>Instruction 06:</b> Before submitting, make sure that you have <b>not deleted, changed, or added anything</b> outside the Solution cells.</li>
#     </ul>
# </div>
#
# <div class="alert alert-block alert-warning">
#     <b>Important:</b> This programming assignment is <b>automatically evaluated</b>. If you do not follow the instructions above or change the required notebook format, your assignment may not be evaluated correctly. You may receive <b>no score</b> even if your code works correctly.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 1: Convert negative numbers in a List to positive**
#
# You are given a list of integers `nums`. Write a Python program using **only List Comprehension** to create and print a new list from `nums` where all negative numbers are converted to their positive equivalents, while positive numbers remain unchanged.
#
# **Note the following constraints:**
# *   The variable `nums` is already defined for you. Avoid assigning your own permanent values to it in your final solution.
# *   Ensure that your solution handles lists of varying lengths.
# *   **Important:** You must solve this using a single list comprehension. Standard multi-line `for` loops will fail the test.
#
# ### **Expected Output**
# For `nums = [-10, 50, 45, 1, 10, -33]`, your program should print:
# > [10, 50, 45, 1, 10, 33]
#
# ### **Do's**
# *   Ensure your final output is the newly generated list printed to the console.
# *   Define a temporary `nums` list to test your code locally, but **remove or comment it out before submitting**.
#
# ### **Don'ts**
# *   Do not use standard multi-line `for` block loops; you must use Python's list comprehension syntax.
# *   Do not hardcode the expected output.
#
# </div>

# %%
# Base dataset available for local testing
nums = [-10, 50, 45, 1, 10, -33]

# (Note: Hidden test variables will be dynamically injected by the autograder)

# %%
# Solution cell for Problem 1:
# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Autograding evaluation cell: Do not delete or modify this cell.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 2: Find Max scores for multiple subjects**
#
# You are given a nested list, `sscores`, which contains exam scores for students. Each sub-list represents the scores of an individual student across three subjects. Write a Python program using **only List comprehension** to return the maximum score for each subject as a list.
#
# **Sample Nested List:**
# `sscores = [[63, 90, 63], [81, 52, 71], [66, 76, 86], [89, 62, 82], [51, 54, 57]]`
# * The first sub-list `[63, 90, 63]` contains the scores of the first student in three subjects (e.g., Subject 1, Subject 2, and Subject 3).
# * The second sub-list `[81, 52, 71]` contains the scores of the second student, and so on.
#
# **Note the following constraints:**
# * The variable `sscores` is already defined for you. Avoid assigning your own permanent values to it in your final solution.
# * Ensure that your solution handles nested lists of varying lengths (i.e., varying number of students).
# * **Important:** You must solve this using list comprehension. Standard multi-line `for` loops will fail the test.
#
# ### **Expected Output**
# For the sample nested list `sscores`, your program should print:
# > [89, 90, 86]
#
# **Explanation of output:**
# * The first element `89` is the highest score in the first subject.
# * The second element `90` is the highest score in the second subject.
# * The third element `86` is the highest score in the third subject.
#
# ### **Do's**
# * Ensure your final output is the newly generated list printed to the console.
# * Define a temporary `sscores` list to test your code locally, but **remove or comment it out before submitting**.
#
# ### **Don'ts**
# * Do not use standard multi-line `for` block loops; you must use Python's list comprehension syntax.
# * Do not hardcode the expected output.
#
# </div>

# %%
# Base dataset available for local testing
sscores = [
    [63, 90, 63],
    [81, 52, 71],
    [66, 76, 86],
    [89, 62, 82],
    [51, 54, 57]
]

# (Note: Hidden test variables will be dynamically injected by the autograder)

# %%
# Solution cell for Problem 2:
# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Autograding evaluation cell: Do not delete or modify this cell.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 3: Nested List to Nested Tuple**
#
# You are given a nested list named `nested_list`. Write a Python program that converts this nested list into a nested tuple and prints the resulting nested tuple.
#
# **Note the following constraints:**
# *   The variable `nested_list` is already defined for you. Avoid assigning your own permanent values to it in your final solution.
# *   Ensure that your solution handles nested lists of varying lengths and varying data types.
# *   Use only Python concepts that have been taught up until this module.
#
# ### **Expected Output**
# For `nested_list = [[79, 72], [99, 114]]`, your program should print:
# > ((79, 72), (99, 114))
#
# ### **Do's**
# *   Ensure your final output is the generated nested tuple printed to the console.
# *   Define a temporary `nested_list` to test your code locally, but **remove or comment it out before submitting**.
#
# ### **Don'ts**
# *   Do not hardcode the expected output.
# *   Do not merely print a string that looks like a tuple; ensure you actually perform the data structure conversion.
#
# </div>

# %%
# Base dataset available for local testing
nested_list = [[79, 72], [99, 114]]

# (Note: Hidden test variables will be dynamically injected by the autograder)

# %%
# Solution cell for Problem 3:
# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Autograding evaluation cell: Do not delete or modify this cell.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 4: Combine items from multiple lists**
#
# You are given three lists representing different attributes of movies: `movie_names`, `ratings`, and `release_years`.
#
# **Sample Lists:**
# `movie_names = ["The Shawshank Redemption", "The Godfather", "The Dark Knight", "Inception"]`
# `ratings = [9.3, 9.2, 9.0]`
# `release_years = [1994, 1972, 2008, 2010]`
#
# Write a Python program to combine these lists into a **nested tuple** where each sub-tuple contains the complete information (Movie Name, Rating, and Release Year) for each movie.
#
# **Note the following constraints:**
# *   If any attribute is missing for a movie (because the lists are of unequal lengths), that movie should be **excluded** from the final result.
# *   The variables `movie_names`, `ratings`, and `release_years` are already defined for you. Avoid assigning your own permanent values to them in your final solution.
# *   Use only Python concepts that have been taught up until this module.
#
# ### **Expected Output**
# For the sample lists above, your program should print:
# > (('The Shawshank Redemption', 9.3, 1994), ('The Godfather', 9.2, 1972), ('The Dark Knight', 9.0, 2008))
#
# ### **Do's**
# *   Ensure your final output is the generated nested tuple printed to the console.
# *   Ensure your solution can handle test cases where any of the three lists are completely empty.
#
# ### **Don'ts**
# *   Do not hardcode the expected output.
# *   Do not manually iterate and check the lengths of the lists with complex nested `if` statements; there is a built-in Python function that handles unequal list combinations automatically.
#
# </div>

# %%
# Base dataset available for local testing[cite: 16]
movie_names = ["The Shawshank Redemption", "The Godfather", "The Dark Knight", "Inception"]
ratings = [9.3, 9.2, 9.0]
release_years = [1994, 1972, 2008, 2010]

# (Note: Hidden test variables will be dynamically injected by the autograder)

# %%
# Solution cell for Problem 4:
# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Autograding evaluation cell: Do not delete or modify this cell.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 5: Parse Movie information**
#
# You are provided with a raw list `movies`, which contains movie attributes in a flat format. This list is organized such that each set of **five** consecutive attributes corresponds to one movie, and their order is consistent throughout the list.
#
# Assume the list `movies` is structured in repeating blocks of five:
# * Title: Movie's name
# * Year: Movie's release year
# * Rating: Movie's IMDb rating
# * Reviews: Number of reviews the movie has
# * Director: Name of movie's director
#
# Write a Python program to parse this flat list and create a **nested list** where each sub-list represents the 5 attributes of a single movie. Finally, print the nested list.
#
# **Note the following constraints:**
# * The list `movies` is predefined. Avoid assigning your own permanent values to it in your final solution.
# * Ensure that your solution correctly handles `movies` lists of varying lengths (but always multiples of 5).
# * Use only Python concepts that have been taught up until this module (e.g., loops, list indexing, and slicing).
#
# ### **Expected Output**
# For the below value of `movies`:
# `movies = ['The Departed', 2006, 8.5, 937414, 'Martin Scorsese', 'The Dark Knight Rises', 2012, 8.5, 1222645, 'Christopher Nolan']`
#
# Your program should print:
# > [['The Departed', 2006, 8.5, 937414, 'Martin Scorsese'], ['The Dark Knight Rises', 2012, 8.5, 1222645, 'Christopher Nolan']]
#
# ### **Do's**
# * Ensure your final output is the generated nested list printed to the console.
# * Define a temporary `movies` list to test your code locally, but **remove or comment it out before submitting**.
#
# ### **Don'ts**
# * Do not hardcode the expected output.
# * Do not permanently modify the original `movies` list; build a new nested list instead.
#
# </div>

# %%
# Base dataset available for local testing
movies = [
    'The Departed', 2006, 8.5, 937414, 'Martin Scorsese', 
    'The Dark Knight Rises', 2012, 8.5, 1222645, 'Christopher Nolan', 
    'Whiplash', 2014, 8.5, 477276, 'Damien Chazelle'
]

# (Note: Hidden test variables will be dynamically injected by the autograder)

# %%
# Solution cell for Problem 5:
# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Autograding evaluation cell: Do not delete or modify this cell.
