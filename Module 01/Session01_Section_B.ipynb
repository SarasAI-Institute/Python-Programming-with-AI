# %% [markdown]
# # **Section 01 : Arithmetic Operations**

# %%
200 - 20
# Out:
# 180

# %%
200 + 20
# Out:
# 220

# %%
8 * 5
# Out:
# 40

# %%
4000 / 100
# Out:
# 40.0

# %% [markdown]
# # **Section 02 : Comparison Operations**
# - Return a Boolean output ('False' or 'True')

# %%
10 > 100
# Out:
# False

# %%
100 >= 100
# Out:
# True

# %%
45 == 45
# Out:
# True

# %% [markdown]
# # **Section 03 : Variables**

# %%
name = 'Gaurav'

# %%
name
# Out:
# 'Gaurav'

# %%
grade = 'B'

# %%
word = "don't"

# %%
comment = """ "I am not happy" """

# %%
x = '5'

# %%
movie01_rating = 9.1

# %%
movie02_rating = 8.7

# %%
movie01_rating > movie02_rating
# Out:
# True

# %%
A = 100
B = 10

# %%
A+B
# Out:
# 110

# %%
A-B
# Out:
# 90

# %%
A*B
# Out:
# 1000

# %%
A/B
# Out:
# 10.0

# %%
80 + 5
# Out:
# 85

# %%
80 - 5
# Out:
# 75

# %%
80 * 5
# Out:
# 400

# %%
80 / 5
# Out:
# 16.0
