# %% [markdown]
# <div class="alert alert-block alert-warning" style="margin-bottom: 10px;">
#
# Before submitting this assignment, please ensure everything runs as expected.
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE".
#
# **Mandatory Step for Autograding:**
# You must provide your Name and Email ID in the designated cell below. **This information MUST be entered in ALL CAPITAL LETTERS.** This is a compulsory requirement; failure to format your details exactly as requested will cause the autograding system to fail, and your assignment will not be evaluated.
#
# </div>

# %%
NAME = ""
EMAIL_ID = ""

# %% [markdown]
# <div class="alert alert-block alert-warning" style="margin-bottom: 10px;">
#     <h4 style="margin-top: 0px;"><b>Important Instructions for Grading</b></h4>
#     <p style="margin-bottom: 0px;">Please read all the instructions carefully before starting. These instructions apply to the entire notebook. Following them will help your notebook get graded correctly.
#         Please note the color coding used in this notebook: <b>Yellow cells</b> contain general instructions and guidelines, while <b>Blue cells</b> contain the actual problem statements and cells are locked as read-only to ensure the autograder functions correctly. Do not attempt to unlock or bypass these restrictions.</li>
#     </p>
# </div>
#
# <div class="alert alert-block alert-warning" style="margin-bottom: 10px;">
#     <ul style="line-height: 1.8; margin-bottom: 0px;">
#         <li><b>Instruction 01:</b> Please add your name and email in the designated cell at the top of the notebook before you begin.</li>
#         <li><b>Instruction 02:</b> Do not delete this instruction cell, and do not delete the cell directly above it.</li>
#         <li><b>Instruction 03:</b> Do not <b>make any changes</b> to the notebook, except where you are asked to write your solution code.</li>
#         <li><b>Instruction 04:</b> Write your solution code <b>only</b> in the cells marked as shown below:
#     <br><br>
#     <code># ------------- Solution cell for Problem -------------</code><br>
#     <br>
#
# </li>
#         <li><b>Instruction 05:</b> For each question in this assignment, the required variables have already been defined for you with values that are hidden from you. Your task is to use these variables in your solution; <b>do not create or assign values to them in this notebook</b>.
#
# If you want to test your solution with different values, you can do so in a **separate Google Colab notebook, Jupyter notebook, or any other IDE**. You may assign your own values there and test your code with different inputs to make sure it works correctly.
#
# Once you are satisfied with your solution, copy the **final code only** into the appropriate **Solution cell** in this notebook. In the Solution cell, use the variable names provided in each question exactly as given, without declaring or assigning any values to them.
#
# </li>
#         <li><b>Instruction 06:</b> Before submitting, make sure that you have <b>not deleted, changed, or added anything</b> outside the Solution cells.</li>
#     </ul>
# </div>
#
# <div class="alert alert-block alert-warning">
#     <b>Important:</b> This programming assignment is <b>automatically evaluated</b>. If you do not follow the instructions above or change the required notebook format, your assignment may not be evaluated correctly. You may receive <b>no score</b> even if your code works correctly.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 1: Print Multiplication Table**
#
# Write a Python program that prints the multiplication table of a given integer `n` from 1 to 10.
#
# **Note the following strict constraints for this problem:**
# * The variable `n` is already defined for you.
# * You are **NOT** supposed to use loops (`for` or `while`).
# * You are **NOT** supposed to use conditional statements (`if`, `elif`, `else`).
# * You are **NOT** supposed to use functions (including user-defined functions) or any libraries.
#
# ### **Expected Output**
# For `n = 6`, your program should print exactly:
# ```
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# ```
#
# ### **Do's**
# * Use basic `print()` statements and mathematical operators to compute the values.
# * Use Python's f-strings (e.g., `f"{n} x 1 = {n*1}"`) to format the output exactly as shown.
# * Use the provided temporary variable`n = 6` to test your code locally.
#
# ### **Don'ts**
# * Do not declare your own permanent value against the variable `n`.
# * Do not use loops, conditionals, or functions to bypass the manual printing requirement.
#
# </div>

# %%
# Base dataset for local testing
n = 6

# (Note: Hidden test variables will be dynamically injected by the autograder)

# %%
# Solution cell for problem 1:
# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Autograding evaluation cell: Do not delete or modify this cell.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 2: Format Movie Information**
#
# Write a Python program that takes movie information as input and displays a formatted output with key details about the movie. The program should use the provided variables and `print()` statements to generate the exact output.
#
# You are provided with the following predefined variables:
# * `movie_name` (string)
# * `movie_director` (string)
# * `movie_rating` (float)
# * `movie_release_year` (int)
# * `movie_genre` (string)
# * `movie_reviews` (string)
# * `movie_revenue` (string)
#
# ### **Expected Output**
# For `movie_name = "The Dark Knight"`, `movie_genre = "Action, Crime, Drama"`, `movie_director = "Christopher Nolan"`, `movie_release_year = 2008`, `movie_rating = 9.0`, and `movie_revenue = "$1.005 billion"`,
#
# your program should print exactly:
#
# > 'The Dark Knight' is an Action, Crime, Drama movie directed by Christopher Nolan. It was released in 2008 and currently holds an IMDB rating of 9.0. The film's box office success was unprecedented, grossing over $1.005 billion worldwide. If you enjoy watching Action, Crime, Drama movies, 'The Dark Knight' is a must-see cinematic masterpiece.
#
# ### **Do's**
# * Use Python's f-strings to inject the variables into your print statements.
# * Use the `end=' '` parameter in your `print()` functions if you wish to combine multiple print statements into a single continuous paragraph.
# * Pay close attention to punctuation, spacing, and capitalization in the expected output.
#
# ### **Don'ts**
# * Do not declare your own permanent values against the given variables.
# * Do not hardcode the movie details into your print statements.
#
# </div>

# %%
# Base dataset available for local testing
movie_name = "The Shawshank Redemption"
movie_director = "Frank Darabont"
movie_rating = 9.2
movie_release_year = 1994
movie_genre = "Drama"
movie_reviews = "Critically acclaimed for its powerful story, excellent performances, and uplifting message"
movie_revenue = "$28.34 million"

# (Note: Hidden test variables will be dynamically injected by the autograder)

# %%
# Solution cell for problem 2:
# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Autograding evaluation cell: Do not delete or modify this cell.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 3: Fetch Movie Information**
#
# You are provided with four predefined lists containing movie metadata:
#
# * `m_name = ['prometheus', 'split', 'sing', 'suicide squad', 'the great wall']`
# * `m_year = [2012, 2016, 2016, 2016, 2017]`
# * `m_rating = [8.1, 7.5, 6.7, 5.3, 7.1]`
# * `m_reviews = [485820, 157606, 60975, 393727, 56036]`
#
# You are also provided with a variable `mov_name` containing the target title. Your task is to write a Python program that locates `mov_name` and prints its details in the exact format shown below.
#
# ### **Expected Output**
# For `mov_name = 'the great wall'`, your program should output:
# ```text
# Movie Name : the great wall
# Movie Release Year : 2017
# Movie Rating : 7.1
# Movie Reviews : 56036
# ```
#
# ### **Do's**
# * Use `m_name.index(mov_name)` to locate the movie's index.
# * Use that index to pull the release year, rating, and review count from `m_year`, `m_rating`, and `m_reviews`.
# * Match the exact label and colon spacing: `Movie Name : <name>`, etc.
# * Use the provided temporary variable `mov_name = 'split'` to test your code locally.
#
# ### **Don'ts**
# * Do not modify or overwrite the predefined lists (`m_name`, `m_year`, `m_rating`, `m_reviews`).
# * Do not leave a hardcoded `mov_name` inside your submitted solution, or it will override the autograder's test cases.
# * Do not use custom functions (`def`) or loops (`for`, `while`).
#
# </div>

# %%
# Base dataset available for local testing
m_name = ['prometheus', 'split', 'sing', 'suicide squad', 'the great wall']
m_year = [2012, 2016, 2016, 2016, 2017]
m_rating = [8.1, 7.5, 6.7, 5.3, 7.1]
m_reviews = [485820, 157606, 60975, 393727, 56036]

# Temporary test variable (You can change this to test different movies)
mov_name = 'split'
# (Note: Hidden test variables will be dynamically injected by the autograder)

# %%
# Solution cell for Problem 3:
# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Autograding evaluation cell: Do not delete or modify this cell.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 4: Compute Average Scores**
#
# You are given a list named `scores` that contains IQ scores for three different sections (A, B and C) of a class. You are also provided with three integer variables `a`, `b` and `c` which represent the number of students in the respective sections. The scores for these sections are stored consecutively in the list such that:
#
# * Scores for the first `a` students belong to Section A
# * Scores for the next `b` students belong to Section B
# * Scores for the next `c` students belong to Section C
#
# Your task is to write a Python program that computes the Average scores for the three sections and prints them.
#
# ### **Expected Output**
# For `scores = [10, 20, 30, 40, 10, 20, 10, 20, 30, 40, 50]` and `a, b, c` as `4, 2, 5` respectively, your program should print:
# `25.0 15.0 30.0`
#
# ### **Do's**
# * Use list slicing (e.g., `scores[:a]`) to extract the scores for each section.
# * Calculate the average by dividing the `sum()` of the slice by its `len()`.
# * Print the three averages separated by spaces in a single `print()` statement.
# * Ensure your logic dynamically handles lists of varying lengths based on `a`, `b`, and `c`.
#
# ### **Don'ts**
# * Do not modify or reassign the predefined `scores`, `a`, `b`, or `c` variables.
# * Do not hardcode the averages or indices.
# * Do not use custom functions (`def`) or loops (`for`, `while`).
#
# </div>

# %%
# Base dataset available for local testing
scores = [10, 20, 30, 40, 10, 20, 10, 20, 30, 40, 50]
a, b, c = 4, 2, 5
# (Note: Hidden test variables will be dynamically injected by the autograder)

# %%
# Solution cell for Problem 4:
# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Autograding evaluation cell: Do not delete or modify this cell.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 5: Check for Palindrome**
#
# Write a Python program that checks whether a given string `word` is a palindrome. A palindrome is a word that reads the exact same forwards and backwards (e.g., "madam" or "radar").
#
# Your program should evaluate the word and print `True` if it is a palindrome, and `False` if it is not.
#
# **Note the following strict constraints for this problem:**
# * The variable `word` is already defined for you.
# * You are **NOT** supposed to use loops (`for` or `while`).
# * You are **NOT** supposed to use conditional statements (`if`, `elif`, `else`).
# * You are **NOT** supposed to use functions or libraries.
#
# ### **Expected Output**
# For `word = "hello"`, your program should print exactly:
#
# > False
#
# ### **Do's**
# * Use Python's string slicing feature to reverse the string.
# * Use the equality operator (`==`) to compare the original string to the reversed string.
# * Print the resulting boolean value directly.
# * Use the provided temporary variable `word = "racecar"` to test your code locally.
#
# ### **Don'ts**
# * Do not declare your own permanent value against the variable `word`.
# * Do not use loops or `if/else` statements to check the letters one by one.
#
# </div>

# %%
# Base dataset available for local testing
word = "racecar"

# (Note: Hidden test variables will be dynamically injected by the autograder)

# %%
# Solution cell:
# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Autograding evaluation cell: Do not delete or modify this cell.
