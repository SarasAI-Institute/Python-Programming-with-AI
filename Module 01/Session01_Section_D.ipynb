# %% [markdown]
# ### **Arithmetic Operators**

# %%
25 + 15 + 50
# Out:
# 90

# %%
25 + 15 - 50 * 2
# Out:
# -60

# %%
100 / 50
# Out:
# 2.0

# %%
30 % 7
# Out:
# 2

# %%
12 % 7
# Out:
# 5

# %% [markdown]
# ### **Comparison Operators**
# - Always returns a Boolean (True or False) output

# %%
23 < 100
# Out:
# True

# %%
23 > 100
# Out:
# False

# %%
45 == 50
# Out:
# False

# %%
100 == 100
# Out:
# True

# %%
# ---- Is 100 different than 100 ?

100 != 100

# ---- Is 100 different than 100 ?
# Out:
# False

# %% [markdown]
# ### **Variables**

# %%
x = 90

# %%
12 % 2 == 0
# Out:
# True

# %%
13 % 2 == 0
# Out:
# False

# %%
x = 9

x % 2 == 0
# Out:
# False
