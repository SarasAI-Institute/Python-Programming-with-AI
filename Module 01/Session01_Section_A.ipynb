# %% [markdown]
# # **Arithmetic Operations**
# - This section covers examples of Arithmetic operations

# %%
# Comment : This is an addition operation
10 + 200
# Out:
# 210

# %%
100 - 20
# Out:
# 80

# %%
10 * 20
# Out:
# 200

# %%
# Divison operation gives a Float as the output

20 / 10  # Divison operation gives a Float as the output

# Divison operation gives a Float as the output
# Out:
# 2.0

# %% [markdown]
# # **Variable Creation**
# - Creating variables of different type

# %%
section_A_monitor = "Saurav"

# %%
section_B_monitor = "Anshi"

# %%
section_B_monitor
# Out:
# 'Anshi'

# %%
section_A_monitor
# Out:
# 'Saurav'

# %%
A = 100
B = 20

# %%
A + B
# Out:
# 120

# %%
C * 10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1770/1976504319.py in <cell line: 0>()
# ----> 1 C * 10
#
# NameError: name 'C' is not defined

# %%
A = 50
B = 10

# %%
A+B
# Out:
# 60

# %%
A-B
# Out:
# 40

# %%
A*B
# Out:
# 500

# %%
A/B
# Out:
# 5.0

# %%
A
# Out:
# 50

# %%
B
# Out:
# 10
