# %% [markdown]
# <div class="alert alert-block alert-warning" style="margin-bottom: 10px;">
#
# Before submitting this assignment, please ensure everything runs as expected.
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE".
#
# **Mandatory Step for Autograding:**
# You must provide your Name and Email ID in the designated cell below. **This information MUST be entered in ALL CAPITAL LETTERS.** This is a compulsory requirement; failure to format your details exactly as requested will cause the autograding system to fail, and your assignment will not be evaluated.
#
# </div>

# %%
NAME = ""
EMAIL_ID = ""

# %% [markdown]
# <div class="alert alert-block alert-warning" style="margin-bottom: 10px;">
#     <h4 style="margin-top: 0px;"><b>Important Instructions for Grading</b></h4>
#     <p style="margin-bottom: 0px;">Please read all the instructions carefully before starting. These instructions apply to the entire notebook. Following them will help your notebook get graded correctly.
#         Please note the color coding used in this notebook: <b>Yellow cells</b> contain general instructions and guidelines, while <b>Blue cells</b> contain the actual problem statements and cells are locked as read-only to ensure the autograder functions correctly. Do not attempt to unlock or bypass these restrictions.</li>
#     </p>
# </div>
#
# <div class="alert alert-block alert-warning" style="margin-bottom: 10px;">
#     <ul style="line-height: 1.8; margin-bottom: 0px;">
#         <li><b>Instruction 01:</b> Please add your name and email in the designated cell at the top of the notebook before you begin.</li>
#         <li><b>Instruction 02:</b> Do not delete this instruction cell, and do not delete the cell directly above it.</li>
#         <li><b>Instruction 03:</b> Do not <b>make any changes</b> to the notebook, except where you are asked to write your solution code.</li>
#         <li><b>Instruction 04:</b> Write your solution code <b>only</b> in the cells marked as shown below:
#     <br><br>
#     <code># ------------- Solution cell for Problem -------------</code><br>
#     <br>
#
# </li>
#         <li><b>Instruction 05:</b> For each question in this assignment, the required variables have already been defined for you with values that are hidden from you. Your task is to use these variables in your solution; <b>do not create or assign values to them in this notebook</b>.
#
# If you want to test your solution with different values, you can do so in a **separate Google Colab notebook, Jupyter notebook, or any other IDE**. You may assign your own values there and test your code with different inputs to make sure it works correctly.
#
# Once you are satisfied with your solution, copy the **final code only** into the appropriate **Solution cell** in this notebook. In the Solution cell, use the variable names provided in each question exactly as given, without declaring or assigning any values to them.
#
# </li>
#         <li><b>Instruction 06:</b> Before submitting, make sure that you have <b>not deleted, changed, or added anything</b> outside the Solution cells.</li>
#     </ul>
# </div>
#
# <div class="alert alert-block alert-warning">
#     <b>Important:</b> This programming assignment is <b>automatically evaluated</b>. If you do not follow the instructions above or change the required notebook format, your assignment may not be evaluated correctly. You may receive <b>no score</b> even if your code works correctly.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 1: Sum of Natural Numbers**
#
# Find the sum of the first `N` natural numbers using this formula: `N * (N + 1) / 2`
#
# You are given two variables, `n1` and `n2`, with values already assigned to them. The values are hidden, so **do not assign new values to `n1` or `n2`**.
#
# Your task is to write the above mathematical expressions for `n1` and `n2` and:
#
# * Calculate the sum for `n1` natural numbers and store it in `sum_n1`
# * Calculate the sum for `n2` natural numbers and store it in `sum_n2`
# * Use `//` or another method to make sure the final answers are integers, not decimals.
#
# ### **Example of expected output**
#
# If `n1 = 5` and `n2 = 10`, then :
#
# * `sum_n1` should be `15`
# * `sum_n2` should be `55`
#
# ### **Do's**
#
# * Use `n1` and `n2` in your mathematical expressions. **Avoid declaring your own values against these variables**
# * Use the exact variable names `sum_n1` and `sum_n2` for storing the sum of natural numbers
#
#
# ### **Don'ts**
#
# * Do not write the final answers directly, such as `sum_n1 = 15` or `sum_n2 =55`
# * Do not print your outputs, i.e. **avoid writing** `print(sum_n1)` or `print(sum_n2)`
#
# </div>

# %%
# This cell is reserved for the autograder. No action is required here.

# %%
# Solution cell for Problem 1:
# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Evaluation Cell: The autograder will verify your answers here. Do not delete.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 2: Variable Swap**
#
# Swap the values of two integer variables **without using any extra variables**.
#
# You are given two pairs of variables with hidden values:
#
# * `value_x1` and `value_y1`
# * `value_x2` and `value_y2`
#
# Your task is to write the swapping logic for **both pairs** so that the value of each variable is exchanged with the other variable in its pair.
#
# ### **Example of expected output**
#
# If `value_x1 = 100` and `value_y1 = 5` initially, then after the swap:
#
# * `value_x1` should be `5`
# * `value_y1` should be `100`
#
# Apply the same logic to `value_x2` and `value_y2`.
#
# ### **Do's**
#
# * Use the exact variable names provided: `value_x1`, `value_y1`, `value_x2`, and `value_y2`.
# * Apply your swapping logic to **both pairs**.
#
# ### **Don'ts**
#
# * **Do not declare your own values against the given variables.**
# * Do not use any extra or temporary variable for the swap, such as `temp`.
# * Do not hardcode the swapped values.
# * Do not print the outputs.
#
# </div>

# %%
# This cell is reserved for the autograder. No action is required here.

# %%
# Solution cell for Problem 2:

# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Evaluation Cell: The autograder will verify your answers here. Do not delete.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 3: Check for Perfect Square**
#
# A **perfect square** is a number that can be written as the product of a whole number multiplied by itself.
#
# For example: `9 = 3 × 3`, `25 = 5 × 5`, and `49 = 7 × 7`.
#
# You are given two variables, `num1` and `num2`, with values already assigned to them. The values are hidden, so **do not assign new values to `num1` or `num2`**.
#
# Your task is to check whether each number is a perfect square or not.
#
# * Check whether `num1` is a perfect square and store the result in `is_num1_square` as either `True` or `False`
# * Check whether `num2` is a perfect square and store the result in `is_num2_square` as either `True` or `False`
#
#
# ### **Example of expected output**
#
# If `num1 = 81`, then:
#
# * `is_num1_square` should be `True`
#
# If `num2 = 80`, then:
#
# * `is_num2_square` should be `False`
#
# ### **Do's**
#
# * Use `num1` and `num2` in your expressions. **Avoid declaring your own values against these variables**
# * Use the exact variable names `is_num1_square` and `is_num2_square` for storing your answers
#
# ### **Don'ts**
#
# * Do not use conditional statements such as `if`, `elif`, or `else`
# * Do not use library-based functions such as `math.sqrt()`
# * Do not use custom functions (`def`) or loops (`for`, `while`)
# * Do not write the final answers directly, such as `is_num1_square = True`
# * Do not print your outputs, i.e. **avoid writing** `print(is_num1_square)` or `print(is_num2_square)`
#
# </div>

# %%
# This cell is reserved for the autograder. No action is required here.

# %%
# Solution cell for Problem 3:

# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Evaluation Cell: The autograder will verify your answers here. Do not delete.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 4: Check Divisibility by 2, 4, and 5**
#
# Write a Python program to check whether a given integer is divisible by **2, 4, and 5** (all of them).
#
# You are given two variables, `v1` and `v2`, with values already assigned to them. The values are hidden, so **do not assign new values to `v1` or `v2`**.
#
# Your task is to check the divisibility of both numbers and:
#
# * Check whether `v1` is divisible by 2, 4, and 5, and store the result in `is_v1_divisible` as `True` or `False`
# * Check whether `v2` is divisible by 2, 4, and 5, and store the result in `is_v2_divisible` as `True` or `False`
#
#
# ### **Example of expected output**
#
# If `v1 = 10`, then:
#
# * `is_v1_divisible` should be `False`, because `10` is not divisible by `4`
#
# If `v2 = 20`, then:
#
# * `is_v2_divisible` should be `True`, because `20` is divisible by all of `2`, `4`, and `5`
#
# ### **Do's**
#
# * Use `v1` and `v2` in your expressions. **Avoid declaring your own values against these variables**
# * Use the exact variable names `is_v1_divisible` and `is_v2_divisible` for storing your answers
#
# ### **Don'ts**
#
# * Do not use conditional statements such as `if`, `elif`, or `else`
# * Do not use custom functions (`def`) or loops (`for`, `while`)
# * Do not write the final answers directly, such as `is_v1_divisible = False`
# * Do not print your outputs, i.e. **avoid writing** `print(is_v1_divisible)` or `print(is_v2_divisible)`
#
# </div>

# %%
# This cell is reserved for the autograder. No action is required here.

# %%
# Solution cell for Problem 4:

# YOUR CODE HERE
raise NotImplementedError()
#---remove this line (raise NotImplementedError()) after writing your code

# %%
# Evaluation Cell: The autograder will verify your answers here. Do not delete.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-bottom: 10px;">
#
# ### **Problem 5: Compute Compound Interest Amount**
#
# Calculate the **Compound Interest (CI) amount** using the given Principal Amount (`P`), Interest Rate (`I`), and Time in Years (`T`).
#
# The formula for Compound Interest is:
#
# `CI = P * (1 + I) ** T - P`
#
# You are given two sets of variables with values already assigned to them. The values are hidden, so **do not assign new values to any of these variables**. Here the interest rate is given as a decimal. For example, `8.5%` is provided as `0.085`.
#
# * `pri_1`, `int_1`, `time_1`
# * `pri_2`, `int_2`, `time_2`
#
# Your task is to calculate the Compound Interest for both sets and:
#
# * Calculate the Compound Interest using `pri_1`, `int_1`, and `time_1`, and store the result in `ci_1`
# * Calculate the Compound Interest using `pri_2`, `int_2`, and `time_2`, and store the result in `ci_2`
# * Round both answers to **two decimal places** using the `round()` function
#
# ### **Example of expected output**
#
# If `pri_1 = 10000`, `int_1 = 0.08`, and `time_1 = 5`, then:
#
# * `ci_1` should be `4693.28` (i.e. rounded to two decimal places)
#
# ### **Do's**
#
# * Use the given variables in your mathematical expressions. **Avoid declaring your own values against these variables**
# * Use the exact variable names `ci_1` and `ci_2` for storing your answers
# * Use the `round()` function to round both answers to **two decimal places**
#
# ### **Don'ts**
#
# * Do not write the final answers directly, such as `ci_1 = 4693.28`
# * Do not use custom functions (`def`) or loops (`for`, `while`)
# * Do not declare your own values against the given variables
# * Do not print your outputs, i.e. **avoid writing** `print(ci_1)` or `print(ci_2)`
#
# </div>

# %%
# This cell is reserved for the autograder. No action is required here.

# %%
# Solution cell for Problem:

# YOUR CODE HERE
raise NotImplementedError()
 #---remove this line (raise NotImplementedError()) after writing your code

# %%
# Evaluation Cell: The autograder will verify your answers here. Do not delete.
