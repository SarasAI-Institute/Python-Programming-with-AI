# %% [markdown]
#  # Module 3: Ungraded Practice Assignment
# Welcome to your practice assignment for Module 3! In this notebook, we will practice generating lists, finding list information, accessing elements, using list methods, and combining lists.
#
# **Instructions:**
# *   Read the text in the markdown cells carefully.
# *   Write your Python code in the empty code cells below each question.
# *   To run a code cell, click the "Play" button on the left or press `Shift + Enter`.
# *   *Reminder: We are not using built-in display functions yet. To see the value of a variable or the result of an operation, simply write the variable name on the very last line of the code cell.*

# %% [markdown]
# ### Q1 - List of Integers with a pattern
#
# ### **Write a Python Program that creates and prints a List of Integers (that follow a certain pattern) by using the provided variable `n`**
# * Required pattern
# ```
# [-n, -n+1, -n+2, ..., 0, ..., n-2, n-1, n]
# ```
# * Note that the variable `n` is already defined for you. Thus avoid assigning your own values to them in your solution
# * You are not supposed to use `For Loops` or any of `List Methods` in your solution for this problem
#
# ### Expected output for Reference
# n = 4
# ```
# [-4, -3, -2, -1, 0, 1, 2, 3, 4]
# ```

# %%
# Write your code here

# %% [markdown]
# ### Q2 - Get Average score
#
# ### **Write a Python program that computes and prints the average of exam scores provided in a List `scores`.**
# * Note that the variable `scores` (which is a List) is already defined for you. Thus avoid assigning your own value to it in your solution
#
# ### Expected output for Reference
# For `scores = [10,20,30]` , your program should print
# ```
# 20.0
# ```

# %%
# Write your code here

# %% [markdown]
# ### Q3 - Girls versus Boys ?
#
# ### **You are given a list `scores` where the scores alternate between girls and boys. Your task is to determine whether the average score of the girls is higher than that of the boys. Print `True` if yes and `False` otherwise**
# * All Girls students scores lie at the Odd positions (.i.e., First, Third, Fifth,...)
# * All Boys students scores lie at the Even positions (.i.e., Second, Fourth, Sixth,...)
# * Note: The list `scores` is predefined. Do not modify or reassign this list in your solution.
# * **You are not supposed to use Conditional Staements (if, elif, else if) in your solution for this problem**
# * Note: Ensure that your solution handles lists of varying lengths and values correctly
#
# ### Expected output for Reference
# For `scores = [1,2,3,4]` , your program should print
# ```
# False
# ```
#
# For `scores = [10,2,30,4,40,6]` , your program should print
# ```
# True
# ```

# %%
# Write your code here to slice the list, calculate averages, and compare

# %% [markdown]
# ### Q4 - Counting Heads and Tails
#
# ### **Write a Python Program that counts the number of Heads and Tails from a provided List `toss_outcomes`**
#
# * Note: The list `toss_outcomes` is predefined. Do not modify or reassign it in your solution.
# * Note: Ensure that your solution handles lists of varying lengths
#
# ### Expected output for Reference
# for the below value of list `toss_outcomes`
# ```
# toss_outcomes = ['Tails', 'Heads', 'Heads', 'Heads']
# ```
# your program should print
# ```
# Count of Heads : 3
# Count of Tails : 1
# ```

# %%
# Write your code here to count the outcomes

# %% [markdown]
# ### Q5 - Finding Highest Scorer
#
# ### **You are provided with a List `scores` which contains exam scores of students. Write a Python program that returns the Roll Number of the student with the Highest Score**
# * Assume there are no Ties, i.e., no Two (or more) students got the same score
# * The scores for the individual students have been stored as per their Roll Numbers 1, 2, 3..... Thus:
#  * The first score in the List belongs to the Student with Roll Number 1
#  * The second score in the List belongs to the Student with Roll Number 2
#  * and so on...
# * Note: The list `scores` is predefined. Do not modify or reassign it in your solution.
# * Note: Ensure that your solution handles lists of varying lengths
#
# ### Expected output for Reference
# for the below value of list `scores`
# ```
# scores = [46, 69, 62, 52, 70, 78, 79, 97, 83, 65]
#
# ```
# your program should print
# ```
# 8
# ```

# %%
# Write your code here to find the Roll Number of the highest scorer

# %% [markdown]
# ### Q6 - Variable Swap
#
# ### **Two variables x and y are created to store integer values. Swap their values by using a third variable (let’s say z)**
# * Note that the variables 'x' and 'y' are already defined for you. Thus avoid assigning your own values to them in your solution

# %%
# The variables are already defined for you
x = 5
y = 100

# Write your code here to swap the variables using a third variable 'z'

# %% [markdown]
# ### Q7 - Email Builder
#
#
# ### Write a Python program that combines the values of the given variables id, provider, and domain to create a proper email address.
# * Note that the variables 'id', 'provider' and 'domain' are already defined for you. Thus avoid assigning your own values to them in your solution
# * Your solution should print the resulting email address without any spaces in between the components.

# %%
# The variables are already defined for you
id = 'randomid'
provider = 'somedomain'
domain = '.com'

# Write your code here to combine the parts into a single email address
