# %% [markdown]
# ### **Arithmetic Operations**

# %%
10 + 5
# Out:
# 15

# %%
10 + 5.5
# Out:
# 15.5

# %%
10 - 5
# Out:
# 5

# %%
10 * 5
# Out:
# 50

# %%
10 / 5
# Out:
# 2.0

# %%
20 % 7
# Out:
# 6

# %% [markdown]
# ### **Comparison Operations**
# - Returns Boolean (`True` or `False`) as the output

# %%
7 > 100
# Out:
# False

# %%
7 < 100
# Out:
# True

# %%
100 == 101
# Out:
# False

# %%
100 != 101
# Out:
# True

# %%
20 % 2 == 0
# Out:
# True

# %%
21 % 2 == 0
# Out:
# False

# %% [markdown]
# ### **Variables**

# %%
marks = 78

# %%
#-- Semester 01----
englishmarks = 78
hindimarks = 81
pythonmarks = 92

# %%
#-- Semester 02----
englishmarks = 82
hindimarks = 90
pythonmarks = 90

# %%
#-- Method 01----
(82+90+90)/3
# Out:
# 87.33333333333333

# %%
#-- Method 02----
(englishmarks + hindimarks + pythonmarks)/3
# Out:
# 87.33333333333333
